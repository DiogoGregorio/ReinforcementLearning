# %%
# %pip install stable-baselines3[extra]
# %pip install gym --upgrade
# %pip install imitation
# Out:
# Requirement already satisfied: stable-baselines3[extra] in c:\users\diogo\anaconda3\lib\site-packages (2.3.0)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in c:\users\diogo\anaconda3\lib\site-packages (from stable-baselines3[extra]) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\diogo\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.26.4)
# Requirement already satisfied: torch>=1.13 in c:\users\diogo\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.2.2)
# Requirement already satisfied: cloudpickle in c:\users\diogo\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.2.1)
# Requirement already satisfied: pandas in c:\users\diogo\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.1.4)
# Requirement already satisfied: matplotlib in c:\users\diogo\anaconda3\lib\site-packages (from stable-baselines3[extra]) (3.8.0)
# Requirement already satisfied: opencv-python in c:\users\diogo\anaconda3\lib\site-packages (from stable-baselines3[extra]) (4.9.0.80)
# Requirement already satisfied: pygame in c:\users\diogo\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.5.2)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\users\diogo\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.16.2)
# Requirement already satisfied: psutil in c:\users\diogo\anaconda3\lib\site-packages (from stable-baselines3[extra]) (5.9.0)
# Requirement already satisfied: tqdm in c:\users\diogo\anaconda3\lib\site-packages (from stable-baselines3[extra]) (4.65.0)
# Requirement already satisfied: rich in c:\users\diogo\anaconda3\lib\site-packages (from stable-baselines3[extra]) (13.3.5)
# Requirement already satisfied: shimmy~=1.3.0 in c:\users\diogo\anaconda3\lib\site-packages (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: pillow in c:\users\diogo\anaconda3\lib\site-packages (from stable-baselines3[extra]) (10.2.0)
# Requirement already satisfied: autorom~=0.6.1 in c:\users\diogo\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: click in c:\users\diogo\anaconda3\lib\site-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (8.1.7)
# Requirement already satisfied: requests in c:\users\diogo\anaconda3\lib\site-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2.31.0)
# Requirement already satisfied: AutoROM.accept-rom-license in c:\users\diogo\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\diogo\anaconda3\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (4.9.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\diogo\anaconda3\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (0.0.4)
# Requirement already satisfied: ale-py~=0.8.1 in c:\users\diogo\anaconda3\lib\site-packages (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]) (0.8.1)
# Requirement already satisfied: absl-py>=0.4 in c:\users\diogo\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\diogo\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.48.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\diogo\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.4.1)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\diogo\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\diogo\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (68.2.2)
# Requirement already satisfied: six>1.9 in c:\users\diogo\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\diogo\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\diogo\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.2.3)
# Requirement already satisfied: filelock in c:\users\diogo\anaconda3\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.13.1)
# Requirement already satisfied: sympy in c:\users\diogo\anaconda3\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (1.12)
# Requirement already satisfied: networkx in c:\users\diogo\anaconda3\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.1)
# Requirement already satisfied: jinja2 in c:\users\diogo\anaconda3\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\diogo\anaconda3\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (2023.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\diogo\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\diogo\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\diogo\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\diogo\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\diogo\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\diogo\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\diogo\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\diogo\anaconda3\lib\site-packages (from pandas->stable-baselines3[extra]) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\diogo\anaconda3\lib\site-packages (from pandas->stable-baselines3[extra]) (2023.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\diogo\anaconda3\lib\site-packages (from rich->stable-baselines3[extra]) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\diogo\anaconda3\lib\site-packages (from rich->stable-baselines3[extra]) (2.15.1)
# Requirement already satisfied: colorama in c:\users\diogo\anaconda3\lib\site-packages (from tqdm->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: importlib-resources in c:\users\diogo\anaconda3\lib\site-packages (from ale-py~=0.8.1->shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]) (6.4.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\diogo\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->stable-baselines3[extra]) (0.1.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\diogo\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\diogo\anaconda3\lib\site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\diogo\anaconda3\lib\site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\diogo\anaconda3\lib\site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\diogo\anaconda3\lib\site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\diogo\anaconda3\lib\site-packages (from sympy->torch>=1.13->stable-baselines3[extra]) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: gym in c:\users\diogo\anaconda3\lib\site-packages (0.26.2)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\diogo\anaconda3\lib\site-packages (from gym) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\diogo\anaconda3\lib\site-packages (from gym) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in c:\users\diogo\anaconda3\lib\site-packages (from gym) (0.0.8)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: imitation in c:\users\diogo\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: gymnasium~=0.29 in c:\users\diogo\anaconda3\lib\site-packages (from gymnasium[classic-control]~=0.29->imitation) (0.29.1)
# Requirement already satisfied: matplotlib in c:\users\diogo\anaconda3\lib\site-packages (from imitation) (3.8.0)
# Requirement already satisfied: numpy>=1.15 in c:\users\diogo\anaconda3\lib\site-packages (from imitation) (1.26.4)
# Requirement already satisfied: torch>=1.4.0 in c:\users\diogo\anaconda3\lib\site-packages (from imitation) (2.2.2)
# Requirement already satisfied: tqdm in c:\users\diogo\anaconda3\lib\site-packages (from imitation) (4.65.0)
# Requirement already satisfied: rich in c:\users\diogo\anaconda3\lib\site-packages (from imitation) (13.3.5)
# Requirement already satisfied: scikit-learn>=0.21.2 in c:\users\diogo\anaconda3\lib\site-packages (from imitation) (1.2.2)
# Requirement already satisfied: seals~=0.2.1 in c:\users\diogo\anaconda3\lib\site-packages (from imitation) (0.2.1)
# Requirement already satisfied: stable-baselines3~=2.0 in c:\users\diogo\anaconda3\lib\site-packages (from imitation) (2.3.0)
# Requirement already satisfied: sacred>=0.8.4 in c:\users\diogo\anaconda3\lib\site-packages (from imitation) (0.8.5)
# Requirement already satisfied: tensorboard>=1.14 in c:\users\diogo\anaconda3\lib\site-packages (from imitation) (2.16.2)
# Requirement already satisfied: huggingface-sb3~=3.0 in c:\users\diogo\anaconda3\lib\site-packages (from imitation) (3.0)
# Requirement already satisfied: optuna>=3.0.1 in c:\users\diogo\anaconda3\lib\site-packages (from imitation) (3.6.1)
# Requirement already satisfied: datasets>=2.8.0 in c:\users\diogo\anaconda3\lib\site-packages (from imitation) (2.19.1)
# Requirement already satisfied: filelock in c:\users\diogo\anaconda3\lib\site-packages (from datasets>=2.8.0->imitation) (3.13.1)
# Requirement already satisfied: pyarrow>=12.0.0 in c:\users\diogo\anaconda3\lib\site-packages (from datasets>=2.8.0->imitation) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in c:\users\diogo\anaconda3\lib\site-packages (from datasets>=2.8.0->imitation) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\diogo\anaconda3\lib\site-packages (from datasets>=2.8.0->imitation) (0.3.8)
# Requirement already satisfied: pandas in c:\users\diogo\anaconda3\lib\site-packages (from datasets>=2.8.0->imitation) (2.1.4)
# Requirement already satisfied: requests>=2.19.0 in c:\users\diogo\anaconda3\lib\site-packages (from datasets>=2.8.0->imitation) (2.31.0)
# Requirement already satisfied: xxhash in c:\users\diogo\anaconda3\lib\site-packages (from datasets>=2.8.0->imitation) (3.4.1)
# Requirement already satisfied: multiprocess in c:\users\diogo\anaconda3\lib\site-packages (from datasets>=2.8.0->imitation) (0.70.16)
# Requirement already satisfied: fsspec<=2024.3.1,>=2023.1.0 in c:\users\diogo\anaconda3\lib\site-packages (from fsspec[http]<=2024.3.1,>=2023.1.0->datasets>=2.8.0->imitation) (2023.10.0)
# Requirement already satisfied: aiohttp in c:\users\diogo\anaconda3\lib\site-packages (from datasets>=2.8.0->imitation) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.21.2 in c:\users\diogo\anaconda3\lib\site-packages (from datasets>=2.8.0->imitation) (0.23.0)
# Requirement already satisfied: packaging in c:\users\diogo\anaconda3\lib\site-packages (from datasets>=2.8.0->imitation) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\diogo\anaconda3\lib\site-packages (from datasets>=2.8.0->imitation) (6.0.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\diogo\anaconda3\lib\site-packages (from gymnasium~=0.29->gymnasium[classic-control]~=0.29->imitation) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\diogo\anaconda3\lib\site-packages (from gymnasium~=0.29->gymnasium[classic-control]~=0.29->imitation) (4.9.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\diogo\anaconda3\lib\site-packages (from gymnasium~=0.29->gymnasium[classic-control]~=0.29->imitation) (0.0.4)
# Requirement already satisfied: pygame>=2.1.3 in c:\users\diogo\anaconda3\lib\site-packages (from gymnasium[classic-control]~=0.29->imitation) (2.5.2)
# Requirement already satisfied: wasabi in c:\users\diogo\anaconda3\lib\site-packages (from huggingface-sb3~=3.0->imitation) (1.1.2)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\diogo\anaconda3\lib\site-packages (from optuna>=3.0.1->imitation) (1.13.1)
# Requirement already satisfied: colorlog in c:\users\diogo\anaconda3\lib\site-packages (from optuna>=3.0.1->imitation) (6.8.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in c:\users\diogo\anaconda3\lib\site-packages (from optuna>=3.0.1->imitation) (2.0.25)
# Requirement already satisfied: docopt<1.0,>=0.3 in c:\users\diogo\anaconda3\lib\site-packages (from sacred>=0.8.4->imitation) (0.6.2)
# Requirement already satisfied: jsonpickle>=2.2.0 in c:\users\diogo\anaconda3\lib\site-packages (from sacred>=0.8.4->imitation) (3.0.4)
# Requirement already satisfied: munch<5.0,>=2.5 in c:\users\diogo\anaconda3\lib\site-packages (from sacred>=0.8.4->imitation) (4.0.0)
# Requirement already satisfied: wrapt<2.0,>=1.0 in c:\users\diogo\anaconda3\lib\site-packages (from sacred>=0.8.4->imitation) (1.14.1)
# Requirement already satisfied: py-cpuinfo>=4.0 in c:\users\diogo\anaconda3\lib\site-packages (from sacred>=0.8.4->imitation) (9.0.0)
# Requirement already satisfied: colorama>=0.4 in c:\users\diogo\anaconda3\lib\site-packages (from sacred>=0.8.4->imitation) (0.4.6)
# Requirement already satisfied: GitPython in c:\users\diogo\anaconda3\lib\site-packages (from sacred>=0.8.4->imitation) (3.1.37)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\diogo\anaconda3\lib\site-packages (from scikit-learn>=0.21.2->imitation) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\diogo\anaconda3\lib\site-packages (from scikit-learn>=0.21.2->imitation) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\diogo\anaconda3\lib\site-packages (from scikit-learn>=0.21.2->imitation) (2.2.0)
# Requirement already satisfied: absl-py>=0.4 in c:\users\diogo\anaconda3\lib\site-packages (from tensorboard>=1.14->imitation) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\diogo\anaconda3\lib\site-packages (from tensorboard>=1.14->imitation) (1.48.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\diogo\anaconda3\lib\site-packages (from tensorboard>=1.14->imitation) (3.4.1)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\diogo\anaconda3\lib\site-packages (from tensorboard>=1.14->imitation) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\diogo\anaconda3\lib\site-packages (from tensorboard>=1.14->imitation) (68.2.2)
# Requirement already satisfied: six>1.9 in c:\users\diogo\anaconda3\lib\site-packages (from tensorboard>=1.14->imitation) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\diogo\anaconda3\lib\site-packages (from tensorboard>=1.14->imitation) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\diogo\anaconda3\lib\site-packages (from tensorboard>=1.14->imitation) (2.2.3)
# Requirement already satisfied: sympy in c:\users\diogo\anaconda3\lib\site-packages (from torch>=1.4.0->imitation) (1.12)
# Requirement already satisfied: networkx in c:\users\diogo\anaconda3\lib\site-packages (from torch>=1.4.0->imitation) (3.1)
# Requirement already satisfied: jinja2 in c:\users\diogo\anaconda3\lib\site-packages (from torch>=1.4.0->imitation) (3.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\diogo\anaconda3\lib\site-packages (from matplotlib->imitation) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\diogo\anaconda3\lib\site-packages (from matplotlib->imitation) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\diogo\anaconda3\lib\site-packages (from matplotlib->imitation) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\diogo\anaconda3\lib\site-packages (from matplotlib->imitation) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\diogo\anaconda3\lib\site-packages (from matplotlib->imitation) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\diogo\anaconda3\lib\site-packages (from matplotlib->imitation) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\diogo\anaconda3\lib\site-packages (from matplotlib->imitation) (2.8.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\diogo\anaconda3\lib\site-packages (from rich->imitation) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\diogo\anaconda3\lib\site-packages (from rich->imitation) (2.15.1)
# Requirement already satisfied: Mako in c:\users\diogo\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna>=3.0.1->imitation) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\diogo\anaconda3\lib\site-packages (from aiohttp->datasets>=2.8.0->imitation) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\diogo\anaconda3\lib\site-packages (from aiohttp->datasets>=2.8.0->imitation) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\diogo\anaconda3\lib\site-packages (from aiohttp->datasets>=2.8.0->imitation) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\diogo\anaconda3\lib\site-packages (from aiohttp->datasets>=2.8.0->imitation) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\diogo\anaconda3\lib\site-packages (from aiohttp->datasets>=2.8.0->imitation) (1.9.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\diogo\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->imitation) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\diogo\anaconda3\lib\site-packages (from requests>=2.19.0->datasets>=2.8.0->imitation) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\diogo\anaconda3\lib\site-packages (from requests>=2.19.0->datasets>=2.8.0->imitation) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\diogo\anaconda3\lib\site-packages (from requests>=2.19.0->datasets>=2.8.0->imitation) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\diogo\anaconda3\lib\site-packages (from requests>=2.19.0->datasets>=2.8.0->imitation) (2024.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\diogo\anaconda3\lib\site-packages (from sqlalchemy>=1.3.0->optuna>=3.0.1->imitation) (3.0.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\diogo\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=1.14->imitation) (2.1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\diogo\anaconda3\lib\site-packages (from GitPython->sacred>=0.8.4->imitation) (4.0.7)
# Requirement already satisfied: pytz>=2020.1 in c:\users\diogo\anaconda3\lib\site-packages (from pandas->datasets>=2.8.0->imitation) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\diogo\anaconda3\lib\site-packages (from pandas->datasets>=2.8.0->imitation) (2023.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\diogo\anaconda3\lib\site-packages (from sympy->torch>=1.4.0->imitation) (1.3.0)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\diogo\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->GitPython->sacred>=0.8.4->imitation) (4.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\diogo\anaconda3\lib\site-packages (2.16.1)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\diogo\anaconda3\lib\site-packages (from tensorflow) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\diogo\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\diogo\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\diogo\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\diogo\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\diogo\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\diogo\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\diogo\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\diogo\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\diogo\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\diogo\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\diogo\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\diogo\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\diogo\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\diogo\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\diogo\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\diogo\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\diogo\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\diogo\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.48.2)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\diogo\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\diogo\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\diogo\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.31.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\diogo\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\diogo\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow) (0.41.2)
# Requirement already satisfied: rich in c:\users\diogo\anaconda3\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (13.3.5)
# Requirement already satisfied: namex in c:\users\diogo\anaconda3\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\diogo\anaconda3\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\diogo\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\diogo\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\diogo\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\diogo\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\diogo\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\diogo\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\diogo\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\diogo\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\diogo\anaconda3\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\diogo\anaconda3\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\diogo\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# []

# %%
import os
import numpy as np
import gym
from gym import Env
from gym.spaces import Discrete, Box
from gym.envs.registration import register
from sklearn.model_selection import train_test_split
from stable_baselines3 import PPO
from stable_baselines3.ppo import MlpPolicy
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from imitation.data import rollout
from imitation.algorithms import bc

# %%
data_folder = os.path.join('data_copy')

# %%
# Define a mapping of body parts to column ranges
body_parts_mapping = {
    'Head': (0, 1),
    'SpineShoulders': (3, 4),
    'SpineMid': (6, 7),
    'LeftShoulder': (9, 10),
    'RightShoulder': (12, 13),
    'LeftElbow': (15, 16),
    'RightElbow': (18, 19),
    'LeftWrist': (21, 22),
    'RightWrist': (24, 25),
    'SpineBase': (27, 28),
    'LeftHip': (30, 31),
    'RightHip': (33, 34),
    'LeftKnee': (36, 37),
    'RightKnee': (39, 40),
    'LeftAnkle': (42, 43),
    'RightAnkle': (45, 46),
}

# %%
# Function to preprocess data
def preprocess_data(data_folder):
    scaled_joint_positions = []  # Store scaled joint positions
    actions = []

    exercise_folders = os.listdir(data_folder)
    exercise_folders.remove('guide')
    exercise_folders.remove('plot') 

    # Define the output folder path
    output_folder = os.path.join("States and Actions")
    os.makedirs(output_folder, exist_ok=True)

    for exercise_folder in exercise_folders:

        exercise_path = os.path.join(data_folder, exercise_folder)
        exercise_path_list = os.listdir(exercise_path)
        
        for typedata_folder in exercise_path_list:
        
            typedata_path = os.path.join(exercise_path, typedata_folder)
            typedata_path_list = os.listdir(typedata_path)

            for typepatient_folder in typedata_path_list:

                typepatient_path = os.path.join(typedata_path, typepatient_folder)
                typepatient_path_list = os.listdir(typepatient_path)

                for patient_folder in typepatient_path_list:

                    patient_path = os.path.join(typepatient_path, patient_folder)
                    patient_path_list = os.listdir(patient_path)

                    for trial_file in patient_path_list:
                        if not trial_file.startswith('.'):  # Skip files/directories starting with a period
                            file_path = os.path.join(patient_path, trial_file)
                            joints_data = read_txt_file(file_path)
        
                            # Extract relevant columns based on body parts mapping
                            extracted_data = extract_body_parts(joints_data)
                            
                            # Print metadata
                            print('-----------------------------------------------')
                            print('TypePatient -', typepatient_folder)
                            print('Exercise -', exercise_folder)
                            print('Typedata -', typedata_folder)
                            print('Patient -', patient_folder)
                            print('Trial -', trial_file)
                            
                            # Initialize list to store scaled coordinates for each instance
                            scaled_instance_coords_list = []
                            
                            # Save the joint positions
                            joint_positions_output_folder = os.path.join(output_folder, typepatient_folder, exercise_folder, typedata_folder, patient_folder)
                            os.makedirs(joint_positions_output_folder, exist_ok=True)
                            joint_positions_file = os.path.join(joint_positions_output_folder, f"{trial_file}_joint_positions.txt")
                            with open(joint_positions_file, 'w') as file:
                                for instance in extracted_data:
                                    #file.write(f"{instance}:\n")
                                    scaled_instance_coords = []
                                    for joint, coords in instance.items():
                                        # Multiply each coordinate by ...
                                        scaled_coords = [round(coord * 100) for coord in coords]
                                        scaled_instance_coords.extend(scaled_coords)
                                        # Write the joint coordinates without brackets and with commas
                                        file.write(','.join(map(str, scaled_coords)))
                                        file.write(",")  # Add a comma between joint coordinates     
                                    file.write("\n")  # Move to the next line after writing all joint coordinates for an instance
                            
                                    # Append scaled joint positions to the list
                                    scaled_instance_coords_list.append(scaled_instance_coords)
                            
                            # Append scaled joint positions to the list
                            scaled_joint_positions.extend(scaled_instance_coords_list)

                            scaled_instance_coords_list = np.array(scaled_instance_coords_list)
                            print(scaled_instance_coords_list.shape)

                            # Process each instance and generate actions
                            instance_actions = generate_actions(scaled_instance_coords_list)
                            actions.extend(instance_actions)
                            
                            # Save the actions as text file
                            actions_output_folder = os.path.join(output_folder, typepatient_folder, exercise_folder, typedata_folder, patient_folder)
                            os.makedirs(actions_output_folder, exist_ok=True)
                            actions_file = os.path.join(actions_output_folder, f"{trial_file}_actions.txt")
                            with open(actions_file, 'w') as file:
                                for action in instance_actions:
                                    file.write(f"{action[0]} {action[1]}\n")

                            #scaled_joint_positions.append(extracted_data)
    
     # Split data into training and testing sets
    train_data, test_data = train_test_split(scaled_joint_positions, test_size=0.2, random_state=42)
    train_actions, test_actions = train_test_split( actions, test_size=0.2, random_state=42)
    
    print('The End')

    
    return train_data, test_data, train_actions, test_actions

# Function to read data from a text file
def read_txt_file(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
        joints_data = [list(map(float, line.split(';'))) for line in lines]
    return joints_data

# Function to extract relevant body parts from joint data
def extract_body_parts(joints_data):
    num_instances = len(joints_data)
    extracted_data = []

    # Iterate over instances
    for instance_idx in range(num_instances):
        instance_data = {}
        spine_base_coords = None  # Initialize spine base coordinates for each instance
        # Iterate over body parts
        for body_part, (start_col, end_col) in body_parts_mapping.items():
            body_part_data = joints_data[instance_idx][start_col:end_col + 1]
            instance_data[body_part] = body_part_data
            if body_part == 'SpineBase':
                spine_base_coords = body_part_data
        # Calculate relative positions of all other joints with respect to spine base coordinates
        for body_part, coords in instance_data.items():
                relative_coords = [coord - spine_base_coord for coord, spine_base_coord in zip(coords, spine_base_coords)]
                instance_data[body_part] = relative_coords
        extracted_data.append(instance_data)

    return extracted_data



def generate_grid(joint_coords, spine_base_coords):
    # Ensure joint_coords is a list, even if it contains only one coordinate pair
    if isinstance(joint_coords[0], int):
        joint_coords = [joint_coords]
    
    # Determine the minimal x and y values of all joints
    min_x = min(coord[0] for coord in joint_coords)
    min_y = min(coord[1] for coord in joint_coords)
    
    # Determine the grid size based on the minimal x and y values
    grid_size_x = max(int((max(coord[0] for coord in joint_coords) - min_x) * 10) + 1, 1)
    grid_size_y = max(int((max(coord[1] for coord in joint_coords) - min_y) * 10) + 1, 1)
    
    print(f"Grid size: {grid_size_x} x {grid_size_y}")

    # Determine grid position of the joint coordinates centered around SpineBase
    grid_x = int((joint_coords[0][0] - spine_base_coords[0] + 0.5) * 10)
    grid_y = int((joint_coords[0][1] - spine_base_coords[1] + 0.5) * 10)
    
    return grid_x, grid_y


# Function to generate actions based on joint positions
def generate_actions(scaled_instance_coords_list):
    actions = []
    current_x_left_wrist = []
    next_x_left_wrist = []
    current_y_left_wrist = []
    next_y_left_wrist = []
    current_x_right_wrist = []
    next_x_right_wrist = []
    current_y_right_wrist = []
    next_y_right_wrist = []

    print(len(scaled_instance_coords_list))
    
    for i in range(len(scaled_instance_coords_list) - 1):
        current_instance = scaled_instance_coords_list[i]
        next_instance = scaled_instance_coords_list[i + 1]

        

        # Extract wrist grid positions for current and next instances
        current_x_left_wrist = current_instance[14]
        next_x_left_wrist = next_instance[14]
        current_y_left_wrist = current_instance[15]
        next_y_left_wrist = next_instance[15]

        current_x_right_wrist = current_instance[16]
        next_x_right_wrist = next_instance[16]
        current_y_right_wrist = current_instance[17]
        next_y_right_wrist = current_instance[17]

        instance_actions = generate_instance_actions(current_x_left_wrist, next_x_left_wrist, current_y_left_wrist, next_y_left_wrist, current_x_right_wrist, next_x_right_wrist, current_y_right_wrist, next_y_right_wrist)
        actions.extend(instance_actions)
    return actions

def generate_instance_actions(current_x_left_wrist, next_x_left_wrist, current_y_left_wrist, next_y_left_wrist, current_x_right_wrist, next_x_right_wrist, current_y_right_wrist, next_y_right_wrist):
    actions = []
    # Generate actions for every other instance
    # Compare wrist positions to determine movement direction for left wrist
    left_movement = compare_positions((current_x_left_wrist, current_y_left_wrist), (next_x_left_wrist, next_y_left_wrist))
    # Compare wrist positions to determine movement direction for right wrist
    right_movement = compare_positions((current_x_right_wrist, current_y_right_wrist), (next_x_right_wrist, next_y_right_wrist))

    # Map grid position comparison to action
    left_action = f"{left_movement}" if left_movement != "Hold" else "Hold"
    right_action = f"{right_movement}" if right_movement != "Hold" else "Hold"

    actions.append((left_action, right_action))
    return actions

# Function to compare grid positions and determine movement direction
def compare_positions(current_grid, next_grid):
    # Calculate the change in coordinates
    delta_x = next_grid[0] - current_grid[0]
    delta_y = next_grid[1] - current_grid[1]
    
    # Determine the movement direction based on the change in coordinates
    if delta_x == 0 and delta_y == 0:
        return "Hold"
    elif delta_x > 0:
        if delta_y > 0:
            return "UpRight"
        elif delta_y < 0:
            return "DownRight"
        else:
            return "Right"
    elif delta_x < 0:
        if delta_y > 0:
            return "UpLeft"
        elif delta_y < 0:
            return "DownLeft"
        else:
            return "Left"
    else:
        if delta_y > 0:
            return "Up"
        elif delta_y < 0:
            return "Down"
    return "no movement detected"  # Default action if no movement detected

# %%
# Step 2: Load the Preprocessed Data
train_data, test_data, train_actions, test_actions = preprocess_data(data_folder)
# Out:
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P01
# Trial - E1_filt_captured_P01_affected_1.txt
# (30, 32)
# 30
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P01
# Trial - E1_filt_captured_P01_affected_10.txt
# (26, 32)
# 26
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P01
# Trial - E1_filt_captured_P01_affected_2.txt
# (28, 32)
# 28
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P01
# Trial - E1_filt_captured_P01_affected_3.txt
# (42, 32)
# 42
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P01
# Trial - E1_filt_captured_P01_affected_4.txt
# (47, 32)
# 47
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P01
# Trial - E1_filt_captured_P01_affected_5.txt
# (48, 32)
# 48
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P01
# Trial - E1_filt_captured_P01_affected_6.txt
# (47, 32)
# 47
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P01
# Trial - E1_filt_captured_P01_affected_7.txt
# (50, 32)
# 50
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P01
# Trial - E1_filt_captured_P01_affected_8.txt
# (50, 32)
# 50
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P01
# Trial - E1_filt_captured_P01_affected_9.txt
# (39, 32)
# 39
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P02
# Trial - E1_filt_captured_P02_affected_1.txt
# (185, 32)
# 185
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P02
# Trial - E1_filt_captured_P02_affected_10.txt
# (94, 32)
# 94
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P02
# Trial - E1_filt_captured_P02_affected_2.txt
# (180, 32)
# 180
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P02
# Trial - E1_filt_captured_P02_affected_3.txt
# (196, 32)
# 196
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P02
# Trial - E1_filt_captured_P02_affected_4.txt
# (154, 32)
# 154
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P02
# Trial - E1_filt_captured_P02_affected_5.txt
# (140, 32)
# 140
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P02
# Trial - E1_filt_captured_P02_affected_6.txt
# (124, 32)
# 124
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P02
# Trial - E1_filt_captured_P02_affected_7.txt
# (166, 32)
# 166
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P02
# Trial - E1_filt_captured_P02_affected_8.txt
# (125, 32)
# 125
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P02
# Trial - E1_filt_captured_P02_affected_9.txt
# (94, 32)
# 94
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P03
# Trial - E1_filt_captured_P03_affected_1.txt
# (147, 32)
# 147
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P03
# Trial - E1_filt_captured_P03_affected_10.txt
# (157, 32)
# 157
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P03
# Trial - E1_filt_captured_P03_affected_2.txt
# (158, 32)
# 158
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P03
# Trial - E1_filt_captured_P03_affected_3.txt
# (157, 32)
# 157
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P03
# Trial - E1_filt_captured_P03_affected_4.txt
# (141, 32)
# 141
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P03
# Trial - E1_filt_captured_P03_affected_5.txt
# (175, 32)
# 175
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P03
# Trial - E1_filt_captured_P03_affected_6.txt
# (172, 32)
# 172
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P03
# Trial - E1_filt_captured_P03_affected_7.txt
# (152, 32)
# 152
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P03
# Trial - E1_filt_captured_P03_affected_8.txt
# (146, 32)
# 146
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P03
# Trial - E1_filt_captured_P03_affected_9.txt
# (146, 32)
# 146
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P04
# Trial - E1_filt_captured_P04_affected_1.txt
# (138, 32)
# 138
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P04
# Trial - E1_filt_captured_P04_affected_10.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P04
# Trial - E1_filt_captured_P04_affected_2.txt
# (109, 32)
# 109
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P04
# Trial - E1_filt_captured_P04_affected_3.txt
# (103, 32)
# 103
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P04
# Trial - E1_filt_captured_P04_affected_4.txt
# (91, 32)
# 91
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P04
# Trial - E1_filt_captured_P04_affected_5.txt
# (88, 32)
# 88
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P04
# Trial - E1_filt_captured_P04_affected_6.txt
# (91, 32)
# 91
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P04
# Trial - E1_filt_captured_P04_affected_7.txt
# (86, 32)
# 86
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P04
# Trial - E1_filt_captured_P04_affected_8.txt
# (85, 32)
# 85
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P04
# Trial - E1_filt_captured_P04_affected_9.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P05
# Trial - E1_filt_captured_P05_affected_1.txt
# (223, 32)
# 223
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P05
# Trial - E1_filt_captured_P05_affected_10.txt
# (217, 32)
# 217
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P05
# Trial - E1_filt_captured_P05_affected_2.txt
# (219, 32)
# 219
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P05
# Trial - E1_filt_captured_P05_affected_3.txt
# (190, 32)
# 190
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P05
# Trial - E1_filt_captured_P05_affected_4.txt
# (170, 32)
# 170
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P05
# Trial - E1_filt_captured_P05_affected_5.txt
# (214, 32)
# 214
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P05
# Trial - E1_filt_captured_P05_affected_6.txt
# (222, 32)
# 222
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P05
# Trial - E1_filt_captured_P05_affected_7.txt
# (195, 32)
# 195
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P05
# Trial - E1_filt_captured_P05_affected_8.txt
# (221, 32)
# 221
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P05
# Trial - E1_filt_captured_P05_affected_9.txt
# (191, 32)
# 191
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P06
# Trial - E1_filt_captured_P06_affected_1.txt
# (253, 32)
# 253
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P06
# Trial - E1_filt_captured_P06_affected_10.txt
# (303, 32)
# 303
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P06
# Trial - E1_filt_captured_P06_affected_2.txt
# (331, 32)
# 331
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P06
# Trial - E1_filt_captured_P06_affected_3.txt
# (265, 32)
# 265
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P06
# Trial - E1_filt_captured_P06_affected_4.txt
# (267, 32)
# 267
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P06
# Trial - E1_filt_captured_P06_affected_5.txt
# (201, 32)
# 201
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P06
# Trial - E1_filt_captured_P06_affected_6.txt
# (226, 32)
# 226
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P06
# Trial - E1_filt_captured_P06_affected_7.txt
# (271, 32)
# 271
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P06
# Trial - E1_filt_captured_P06_affected_8.txt
# (238, 32)
# 238
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P06
# Trial - E1_filt_captured_P06_affected_9.txt
# (293, 32)
# 293
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P07
# Trial - E1_filt_captured_P07_affected_1.txt
# (357, 32)
# 357
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P07
# Trial - E1_filt_captured_P07_affected_10.txt
# (156, 32)
# 156
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P07
# Trial - E1_filt_captured_P07_affected_2.txt
# (146, 32)
# 146
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P07
# Trial - E1_filt_captured_P07_affected_3.txt
# (168, 32)
# 168
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P07
# Trial - E1_filt_captured_P07_affected_4.txt
# (187, 32)
# 187
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P07
# Trial - E1_filt_captured_P07_affected_5.txt
# (151, 32)
# 151
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P07
# Trial - E1_filt_captured_P07_affected_6.txt
# (120, 32)
# 120
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P07
# Trial - E1_filt_captured_P07_affected_7.txt
# (170, 32)
# 170
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P07
# Trial - E1_filt_captured_P07_affected_8.txt
# (141, 32)
# 141
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P07
# Trial - E1_filt_captured_P07_affected_9.txt
# (147, 32)
# 147
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P08
# Trial - E1_filt_captured_P08_affected_1.txt
# (241, 32)
# 241
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P08
# Trial - E1_filt_captured_P08_affected_10.txt
# (156, 32)
# 156
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P08
# Trial - E1_filt_captured_P08_affected_2.txt
# (260, 32)
# 260
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P08
# Trial - E1_filt_captured_P08_affected_3.txt
# (195, 32)
# 195
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P08
# Trial - E1_filt_captured_P08_affected_4.txt
# (165, 32)
# 165
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P08
# Trial - E1_filt_captured_P08_affected_5.txt
# (164, 32)
# 164
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P08
# Trial - E1_filt_captured_P08_affected_6.txt
# (113, 32)
# 113
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P08
# Trial - E1_filt_captured_P08_affected_7.txt
# (123, 32)
# 123
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P08
# Trial - E1_filt_captured_P08_affected_8.txt
# (116, 32)
# 116
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P08
# Trial - E1_filt_captured_P08_affected_9.txt
# (132, 32)
# 132
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P09
# Trial - E1_filt_captured_P09_affected_1.txt
# (363, 32)
# 363
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P09
# Trial - E1_filt_captured_P09_affected_10.txt
# (303, 32)
# 303
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P09
# Trial - E1_filt_captured_P09_affected_2.txt
# (361, 32)
# 361
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P09
# Trial - E1_filt_captured_P09_affected_3.txt
# (274, 32)
# 274
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P09
# Trial - E1_filt_captured_P09_affected_4.txt
# (317, 32)
# 317
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P09
# Trial - E1_filt_captured_P09_affected_5.txt
# (323, 32)
# 323
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P09
# Trial - E1_filt_captured_P09_affected_6.txt
# (280, 32)
# 280
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P09
# Trial - E1_filt_captured_P09_affected_7.txt
# (312, 32)
# 312
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P09
# Trial - E1_filt_captured_P09_affected_8.txt
# (311, 32)
# 311
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P09
# Trial - E1_filt_captured_P09_affected_9.txt
# (233, 32)
# 233
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P10
# Trial - E1_filt_captured_P10_affected_1.txt
# (325, 32)
# 325
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P10
# Trial - E1_filt_captured_P10_affected_10.txt
# (267, 32)
# 267
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P10
# Trial - E1_filt_captured_P10_affected_2.txt
# (241, 32)
# 241
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P10
# Trial - E1_filt_captured_P10_affected_3.txt
# (394, 32)
# 394
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P10
# Trial - E1_filt_captured_P10_affected_4.txt
# (249, 32)
# 249
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P10
# Trial - E1_filt_captured_P10_affected_5.txt
# (261, 32)
# 261
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P10
# Trial - E1_filt_captured_P10_affected_6.txt
# (283, 32)
# 283
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P10
# Trial - E1_filt_captured_P10_affected_7.txt
# (301, 32)
# 301
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P10
# Trial - E1_filt_captured_P10_affected_8.txt
# (367, 32)
# 367
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P10
# Trial - E1_filt_captured_P10_affected_9.txt
# (355, 32)
# 355
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P11
# Trial - E1_filt_captured_P11_affected_1.txt
# (260, 32)
# 260
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P11
# Trial - E1_filt_captured_P11_affected_10.txt
# (225, 32)
# 225
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P11
# Trial - E1_filt_captured_P11_affected_2.txt
# (257, 32)
# 257
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P11
# Trial - E1_filt_captured_P11_affected_3.txt
# (245, 32)
# 245
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P11
# Trial - E1_filt_captured_P11_affected_4.txt
# (250, 32)
# 250
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P11
# Trial - E1_filt_captured_P11_affected_5.txt
# (272, 32)
# 272
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P11
# Trial - E1_filt_captured_P11_affected_6.txt
# (249, 32)
# 249
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P11
# Trial - E1_filt_captured_P11_affected_7.txt
# (257, 32)
# 257
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P11
# Trial - E1_filt_captured_P11_affected_8.txt
# (235, 32)
# 235
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P11
# Trial - E1_filt_captured_P11_affected_9.txt
# (255, 32)
# 255
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P12
# Trial - E1_filt_captured_P12_affected_1.txt
# (315, 32)
# 315
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P12
# Trial - E1_filt_captured_P12_affected_10.txt
# (257, 32)
# 257
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P12
# Trial - E1_filt_captured_P12_affected_2.txt
# (301, 32)
# 301
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P12
# Trial - E1_filt_captured_P12_affected_3.txt
# (330, 32)
# 330
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P12
# Trial - E1_filt_captured_P12_affected_4.txt
# (299, 32)
# 299
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P12
# Trial - E1_filt_captured_P12_affected_5.txt
# (317, 32)
# 317
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P12
# Trial - E1_filt_captured_P12_affected_6.txt
# (191, 32)
# 191
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P12
# Trial - E1_filt_captured_P12_affected_7.txt
# (310, 32)
# 310
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P12
# Trial - E1_filt_captured_P12_affected_8.txt
# (341, 32)
# 341
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P12
# Trial - E1_filt_captured_P12_affected_9.txt
# (355, 32)
# 355
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P13
# Trial - E1_filt_captured_P13_affected_1.txt
# (92, 32)
# 92
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P13
# Trial - E1_filt_captured_P13_affected_10.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P13
# Trial - E1_filt_captured_P13_affected_2.txt
# (91, 32)
# 91
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P13
# Trial - E1_filt_captured_P13_affected_3.txt
# (99, 32)
# 99
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P13
# Trial - E1_filt_captured_P13_affected_4.txt
# (74, 32)
# 74
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P13
# Trial - E1_filt_captured_P13_affected_5.txt
# (95, 32)
# 95
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P13
# Trial - E1_filt_captured_P13_affected_6.txt
# (87, 32)
# 87
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P13
# Trial - E1_filt_captured_P13_affected_7.txt
# (98, 32)
# 98
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P13
# Trial - E1_filt_captured_P13_affected_8.txt
# (105, 32)
# 105
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P13
# Trial - E1_filt_captured_P13_affected_9.txt
# (75, 32)
# 75
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P14
# Trial - E1_filt_captured_P14_affected_1.txt
# (160, 32)
# 160
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P14
# Trial - E1_filt_captured_P14_affected_10.txt
# (254, 32)
# 254
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P14
# Trial - E1_filt_captured_P14_affected_2.txt
# (163, 32)
# 163
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P14
# Trial - E1_filt_captured_P14_affected_3.txt
# (216, 32)
# 216
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P14
# Trial - E1_filt_captured_P14_affected_4.txt
# (220, 32)
# 220
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P14
# Trial - E1_filt_captured_P14_affected_5.txt
# (209, 32)
# 209
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P14
# Trial - E1_filt_captured_P14_affected_6.txt
# (258, 32)
# 258
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P14
# Trial - E1_filt_captured_P14_affected_7.txt
# (192, 32)
# 192
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P14
# Trial - E1_filt_captured_P14_affected_8.txt
# (170, 32)
# 170
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P14
# Trial - E1_filt_captured_P14_affected_9.txt
# (211, 32)
# 211
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P15
# Trial - E1_filt_captured_P15_affected_1.txt
# (212, 32)
# 212
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P15
# Trial - E1_filt_captured_P15_affected_10.txt
# (166, 32)
# 166
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P15
# Trial - E1_filt_captured_P15_affected_2.txt
# (164, 32)
# 164
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P15
# Trial - E1_filt_captured_P15_affected_3.txt
# (162, 32)
# 162
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P15
# Trial - E1_filt_captured_P15_affected_4.txt
# (112, 32)
# 112
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P15
# Trial - E1_filt_captured_P15_affected_5.txt
# (112, 32)
# 112
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P15
# Trial - E1_filt_captured_P15_affected_6.txt
# (148, 32)
# 148
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P15
# Trial - E1_filt_captured_P15_affected_7.txt
# (118, 32)
# 118
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P15
# Trial - E1_filt_captured_P15_affected_8.txt
# (180, 32)
# 180
# -----------------------------------------------
# TypePatient - affected
# Exercise - E1
# Typedata - capture
# Patient - P15
# Trial - E1_filt_captured_P15_affected_9.txt
# (214, 32)
# 214
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P01
# Trial - E1_filt_captured_P01_unaffected_1.txt
# (28, 32)
# 28
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P01
# Trial - E1_filt_captured_P01_unaffected_10.txt
# (33, 32)
# 33
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P01
# Trial - E1_filt_captured_P01_unaffected_2.txt
# (46, 32)
# 46
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P01
# Trial - E1_filt_captured_P01_unaffected_3.txt
# (30, 32)
# 30
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P01
# Trial - E1_filt_captured_P01_unaffected_4.txt
# (25, 32)
# 25
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P01
# Trial - E1_filt_captured_P01_unaffected_5.txt
# (30, 32)
# 30
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P01
# Trial - E1_filt_captured_P01_unaffected_6.txt
# (21, 32)
# 21
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P01
# Trial - E1_filt_captured_P01_unaffected_7.txt
# (28, 32)
# 28
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P01
# Trial - E1_filt_captured_P01_unaffected_8.txt
# (28, 32)
# 28
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P01
# Trial - E1_filt_captured_P01_unaffected_9.txt
# (29, 32)
# 29
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P02
# Trial - E1_filt_captured_P02_unaffected_1.txt
# (79, 32)
# 79
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P02
# Trial - E1_filt_captured_P02_unaffected_10.txt
# (90, 32)
# 90
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P02
# Trial - E1_filt_captured_P02_unaffected_2.txt
# (90, 32)
# 90
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P02
# Trial - E1_filt_captured_P02_unaffected_3.txt
# (74, 32)
# 74
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P02
# Trial - E1_filt_captured_P02_unaffected_4.txt
# (70, 32)
# 70
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P02
# Trial - E1_filt_captured_P02_unaffected_5.txt
# (79, 32)
# 79
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P02
# Trial - E1_filt_captured_P02_unaffected_6.txt
# (90, 32)
# 90
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P02
# Trial - E1_filt_captured_P02_unaffected_7.txt
# (74, 32)
# 74
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P02
# Trial - E1_filt_captured_P02_unaffected_8.txt
# (70, 32)
# 70
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P02
# Trial - E1_filt_captured_P02_unaffected_9.txt
# (79, 32)
# 79
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P03
# Trial - E1_filt_captured_P03_unaffected_1.txt
# (125, 32)
# 125
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P03
# Trial - E1_filt_captured_P03_unaffected_10.txt
# (157, 32)
# 157
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P03
# Trial - E1_filt_captured_P03_unaffected_2.txt
# (157, 32)
# 157
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P03
# Trial - E1_filt_captured_P03_unaffected_3.txt
# (159, 32)
# 159
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P03
# Trial - E1_filt_captured_P03_unaffected_4.txt
# (142, 32)
# 142
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P03
# Trial - E1_filt_captured_P03_unaffected_5.txt
# (102, 32)
# 102
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P03
# Trial - E1_filt_captured_P03_unaffected_6.txt
# (157, 32)
# 157
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P03
# Trial - E1_filt_captured_P03_unaffected_7.txt
# (139, 32)
# 139
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P03
# Trial - E1_filt_captured_P03_unaffected_8.txt
# (138, 32)
# 138
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P03
# Trial - E1_filt_captured_P03_unaffected_9.txt
# (120, 32)
# 120
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P04
# Trial - E1_filt_captured_P04_unaffected_1.txt
# (187, 32)
# 187
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P04
# Trial - E1_filt_captured_P04_unaffected_10.txt
# (102, 32)
# 102
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P04
# Trial - E1_filt_captured_P04_unaffected_2.txt
# (148, 32)
# 148
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P04
# Trial - E1_filt_captured_P04_unaffected_3.txt
# (122, 32)
# 122
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P04
# Trial - E1_filt_captured_P04_unaffected_4.txt
# (111, 32)
# 111
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P04
# Trial - E1_filt_captured_P04_unaffected_5.txt
# (97, 32)
# 97
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P04
# Trial - E1_filt_captured_P04_unaffected_6.txt
# (98, 32)
# 98
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P04
# Trial - E1_filt_captured_P04_unaffected_7.txt
# (114, 32)
# 114
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P04
# Trial - E1_filt_captured_P04_unaffected_8.txt
# (103, 32)
# 103
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P04
# Trial - E1_filt_captured_P04_unaffected_9.txt
# (87, 32)
# 87
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P05
# Trial - E1_filt_captured_P05_unaffected_1.txt
# (121, 32)
# 121
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P05
# Trial - E1_filt_captured_P05_unaffected_10.txt
# (146, 32)
# 146
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P05
# Trial - E1_filt_captured_P05_unaffected_2.txt
# (125, 32)
# 125
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P05
# Trial - E1_filt_captured_P05_unaffected_3.txt
# (155, 32)
# 155
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P05
# Trial - E1_filt_captured_P05_unaffected_4.txt
# (144, 32)
# 144
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P05
# Trial - E1_filt_captured_P05_unaffected_5.txt
# (118, 32)
# 118
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P05
# Trial - E1_filt_captured_P05_unaffected_6.txt
# (143, 32)
# 143
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P05
# Trial - E1_filt_captured_P05_unaffected_7.txt
# (133, 32)
# 133
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P05
# Trial - E1_filt_captured_P05_unaffected_8.txt
# (147, 32)
# 147
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P05
# Trial - E1_filt_captured_P05_unaffected_9.txt
# (170, 32)
# 170
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P06
# Trial - E1_filt_captured_P06_unaffected_1.txt
# (217, 32)
# 217
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P06
# Trial - E1_filt_captured_P06_unaffected_10.txt
# (238, 32)
# 238
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P06
# Trial - E1_filt_captured_P06_unaffected_2.txt
# (149, 32)
# 149
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P06
# Trial - E1_filt_captured_P06_unaffected_3.txt
# (155, 32)
# 155
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P06
# Trial - E1_filt_captured_P06_unaffected_4.txt
# (209, 32)
# 209
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P06
# Trial - E1_filt_captured_P06_unaffected_5.txt
# (181, 32)
# 181
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P06
# Trial - E1_filt_captured_P06_unaffected_6.txt
# (123, 32)
# 123
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P06
# Trial - E1_filt_captured_P06_unaffected_7.txt
# (132, 32)
# 132
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P06
# Trial - E1_filt_captured_P06_unaffected_8.txt
# (224, 32)
# 224
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P06
# Trial - E1_filt_captured_P06_unaffected_9.txt
# (181, 32)
# 181
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P07
# Trial - E1_filt_captured_P07_unaffected_1.txt
# (150, 32)
# 150
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P07
# Trial - E1_filt_captured_P07_unaffected_10.txt
# (156, 32)
# 156
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P07
# Trial - E1_filt_captured_P07_unaffected_2.txt
# (245, 32)
# 245
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P07
# Trial - E1_filt_captured_P07_unaffected_3.txt
# (99, 32)
# 99
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P07
# Trial - E1_filt_captured_P07_unaffected_4.txt
# (94, 32)
# 94
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P07
# Trial - E1_filt_captured_P07_unaffected_5.txt
# (111, 32)
# 111
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P07
# Trial - E1_filt_captured_P07_unaffected_6.txt
# (85, 32)
# 85
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P07
# Trial - E1_filt_captured_P07_unaffected_7.txt
# (139, 32)
# 139
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P07
# Trial - E1_filt_captured_P07_unaffected_8.txt
# (255, 32)
# 255
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P07
# Trial - E1_filt_captured_P07_unaffected_9.txt
# (182, 32)
# 182
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P08
# Trial - E1_filt_captured_P08_unaffected_1.txt
# (262, 32)
# 262
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P08
# Trial - E1_filt_captured_P08_unaffected_10.txt
# (127, 32)
# 127
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P08
# Trial - E1_filt_captured_P08_unaffected_2.txt
# (132, 32)
# 132
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P08
# Trial - E1_filt_captured_P08_unaffected_3.txt
# (176, 32)
# 176
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P08
# Trial - E1_filt_captured_P08_unaffected_4.txt
# (119, 32)
# 119
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P08
# Trial - E1_filt_captured_P08_unaffected_5.txt
# (139, 32)
# 139
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P08
# Trial - E1_filt_captured_P08_unaffected_6.txt
# (128, 32)
# 128
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P08
# Trial - E1_filt_captured_P08_unaffected_7.txt
# (117, 32)
# 117
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P08
# Trial - E1_filt_captured_P08_unaffected_8.txt
# (129, 32)
# 129
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P08
# Trial - E1_filt_captured_P08_unaffected_9.txt
# (124, 32)
# 124
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P09
# Trial - E1_filt_captured_P09_unaffected_1.txt
# (237, 32)
# 237
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P09
# Trial - E1_filt_captured_P09_unaffected_10.txt
# (263, 32)
# 263
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P09
# Trial - E1_filt_captured_P09_unaffected_2.txt
# (214, 32)
# 214
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P09
# Trial - E1_filt_captured_P09_unaffected_3.txt
# (201, 32)
# 201
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P09
# Trial - E1_filt_captured_P09_unaffected_4.txt
# (237, 32)
# 237
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P09
# Trial - E1_filt_captured_P09_unaffected_5.txt
# (241, 32)
# 241
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P09
# Trial - E1_filt_captured_P09_unaffected_6.txt
# (249, 32)
# 249
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P09
# Trial - E1_filt_captured_P09_unaffected_7.txt
# (236, 32)
# 236
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P09
# Trial - E1_filt_captured_P09_unaffected_8.txt
# (229, 32)
# 229
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P09
# Trial - E1_filt_captured_P09_unaffected_9.txt
# (241, 32)
# 241
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P10
# Trial - E1_filt_captured_P10_unaffected_1.txt
# (144, 32)
# 144
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P10
# Trial - E1_filt_captured_P10_unaffected_10.txt
# (151, 32)
# 151
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P10
# Trial - E1_filt_captured_P10_unaffected_2.txt
# (107, 32)
# 107
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P10
# Trial - E1_filt_captured_P10_unaffected_3.txt
# (100, 32)
# 100
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P10
# Trial - E1_filt_captured_P10_unaffected_4.txt
# (103, 32)
# 103
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P10
# Trial - E1_filt_captured_P10_unaffected_5.txt
# (107, 32)
# 107
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P10
# Trial - E1_filt_captured_P10_unaffected_6.txt
# (107, 32)
# 107
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P10
# Trial - E1_filt_captured_P10_unaffected_7.txt
# (138, 32)
# 138
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P10
# Trial - E1_filt_captured_P10_unaffected_8.txt
# (115, 32)
# 115
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P10
# Trial - E1_filt_captured_P10_unaffected_9.txt
# (110, 32)
# 110
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P11
# Trial - E1_filt_captured_P11_unaffected_1.txt
# (165, 32)
# 165
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P11
# Trial - E1_filt_captured_P11_unaffected_10.txt
# (137, 32)
# 137
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P11
# Trial - E1_filt_captured_P11_unaffected_2.txt
# (126, 32)
# 126
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P11
# Trial - E1_filt_captured_P11_unaffected_3.txt
# (142, 32)
# 142
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P11
# Trial - E1_filt_captured_P11_unaffected_4.txt
# (144, 32)
# 144
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P11
# Trial - E1_filt_captured_P11_unaffected_5.txt
# (183, 32)
# 183
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P11
# Trial - E1_filt_captured_P11_unaffected_6.txt
# (139, 32)
# 139
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P11
# Trial - E1_filt_captured_P11_unaffected_7.txt
# (139, 32)
# 139
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P11
# Trial - E1_filt_captured_P11_unaffected_8.txt
# (137, 32)
# 137
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P11
# Trial - E1_filt_captured_P11_unaffected_9.txt
# (151, 32)
# 151
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P12
# Trial - E1_filt_captured_P12_unaffected_1.txt
# (120, 32)
# 120
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P12
# Trial - E1_filt_captured_P12_unaffected_10.txt
# (107, 32)
# 107
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P12
# Trial - E1_filt_captured_P12_unaffected_2.txt
# (124, 32)
# 124
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P12
# Trial - E1_filt_captured_P12_unaffected_3.txt
# (103, 32)
# 103
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P12
# Trial - E1_filt_captured_P12_unaffected_4.txt
# (120, 32)
# 120
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P12
# Trial - E1_filt_captured_P12_unaffected_5.txt
# (117, 32)
# 117
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P12
# Trial - E1_filt_captured_P12_unaffected_6.txt
# (81, 32)
# 81
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P12
# Trial - E1_filt_captured_P12_unaffected_7.txt
# (71, 32)
# 71
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P12
# Trial - E1_filt_captured_P12_unaffected_8.txt
# (98, 32)
# 98
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# Typedata - capture
# Patient - P12
# Trial - E1_filt_captured_P12_unaffected_9.txt
# (97, 32)
# 97
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E1
# ...
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S08
# Trial - E3_filt_captured_S08_unaffected_6.txt
# (146, 32)
# 146
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S08
# Trial - E3_filt_captured_S08_unaffected_7.txt
# (149, 32)
# 149
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S08
# Trial - E3_filt_captured_S08_unaffected_8.txt
# (124, 32)
# 124
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S08
# Trial - E3_filt_captured_S08_unaffected_9.txt
# (141, 32)
# 141
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S09
# Trial - E3_filt_captured_S09_unaffected_1.txt
# (119, 32)
# 119
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S09
# Trial - E3_filt_captured_S09_unaffected_10.txt
# (125, 32)
# 125
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S09
# Trial - E3_filt_captured_S09_unaffected_11.txt
# (126, 32)
# 126
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S09
# Trial - E3_filt_captured_S09_unaffected_12.txt
# (116, 32)
# 116
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S09
# Trial - E3_filt_captured_S09_unaffected_13.txt
# (120, 32)
# 120
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S09
# Trial - E3_filt_captured_S09_unaffected_14.txt
# (127, 32)
# 127
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S09
# Trial - E3_filt_captured_S09_unaffected_15.txt
# (124, 32)
# 124
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S09
# Trial - E3_filt_captured_S09_unaffected_2.txt
# (93, 32)
# 93
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S09
# Trial - E3_filt_captured_S09_unaffected_3.txt
# (96, 32)
# 96
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S09
# Trial - E3_filt_captured_S09_unaffected_4.txt
# (104, 32)
# 104
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S09
# Trial - E3_filt_captured_S09_unaffected_5.txt
# (117, 32)
# 117
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S09
# Trial - E3_filt_captured_S09_unaffected_6.txt
# (118, 32)
# 118
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S09
# Trial - E3_filt_captured_S09_unaffected_7.txt
# (122, 32)
# 122
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S09
# Trial - E3_filt_captured_S09_unaffected_8.txt
# (129, 32)
# 129
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S09
# Trial - E3_filt_captured_S09_unaffected_9.txt
# (124, 32)
# 124
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S10
# Trial - E3_filt_captured_S10_unaffected_1.txt
# (68, 32)
# 68
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S10
# Trial - E3_filt_captured_S10_unaffected_10.txt
# (79, 32)
# 79
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S10
# Trial - E3_filt_captured_S10_unaffected_11.txt
# (86, 32)
# 86
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S10
# Trial - E3_filt_captured_S10_unaffected_12.txt
# (83, 32)
# 83
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S10
# Trial - E3_filt_captured_S10_unaffected_13.txt
# (82, 32)
# 82
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S10
# Trial - E3_filt_captured_S10_unaffected_14.txt
# (129, 32)
# 129
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S10
# Trial - E3_filt_captured_S10_unaffected_15.txt
# (122, 32)
# 122
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S10
# Trial - E3_filt_captured_S10_unaffected_2.txt
# (75, 32)
# 75
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S10
# Trial - E3_filt_captured_S10_unaffected_3.txt
# (75, 32)
# 75
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S10
# Trial - E3_filt_captured_S10_unaffected_4.txt
# (75, 32)
# 75
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S10
# Trial - E3_filt_captured_S10_unaffected_5.txt
# (68, 32)
# 68
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S10
# Trial - E3_filt_captured_S10_unaffected_6.txt
# (72, 32)
# 72
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S10
# Trial - E3_filt_captured_S10_unaffected_7.txt
# (77, 32)
# 77
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S10
# Trial - E3_filt_captured_S10_unaffected_8.txt
# (78, 32)
# 78
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S10
# Trial - E3_filt_captured_S10_unaffected_9.txt
# (99, 32)
# 99
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S11
# Trial - E3_filt_captured_S11_unaffected_1.txt
# (81, 32)
# 81
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S11
# Trial - E3_filt_captured_S11_unaffected_10.txt
# (114, 32)
# 114
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S11
# Trial - E3_filt_captured_S11_unaffected_11.txt
# (80, 32)
# 80
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S11
# Trial - E3_filt_captured_S11_unaffected_12.txt
# (76, 32)
# 76
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S11
# Trial - E3_filt_captured_S11_unaffected_13.txt
# (77, 32)
# 77
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S11
# Trial - E3_filt_captured_S11_unaffected_14.txt
# (76, 32)
# 76
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S11
# Trial - E3_filt_captured_S11_unaffected_15.txt
# (81, 32)
# 81
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S11
# Trial - E3_filt_captured_S11_unaffected_2.txt
# (79, 32)
# 79
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S11
# Trial - E3_filt_captured_S11_unaffected_3.txt
# (81, 32)
# 81
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S11
# Trial - E3_filt_captured_S11_unaffected_4.txt
# (94, 32)
# 94
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S11
# Trial - E3_filt_captured_S11_unaffected_5.txt
# (99, 32)
# 99
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S11
# Trial - E3_filt_captured_S11_unaffected_6.txt
# (81, 32)
# 81
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S11
# Trial - E3_filt_captured_S11_unaffected_7.txt
# (74, 32)
# 74
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S11
# Trial - E3_filt_captured_S11_unaffected_8.txt
# (73, 32)
# 73
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - capture
# Patient - S11
# Trial - E3_filt_captured_S11_unaffected_9.txt
# (71, 32)
# 71
# -----------------------------------------------
# TypePatient - affected
# Exercise - E3
# Typedata - measure
# Patient - P01
# Trial - E3_filt_measured_P01_affected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - affected
# Exercise - E3
# Typedata - measure
# Patient - P02
# Trial - E3_filt_measured_P02_affected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - affected
# Exercise - E3
# Typedata - measure
# Patient - P03
# Trial - E3_filt_measured_P03_affected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - affected
# Exercise - E3
# Typedata - measure
# Patient - P04
# Trial - E3_filt_measured_P04_affected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - affected
# Exercise - E3
# Typedata - measure
# Patient - P05
# Trial - E3_filt_measured_P05_affected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - affected
# Exercise - E3
# Typedata - measure
# Patient - P06
# Trial - E3_filt_measured_P06_affected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - affected
# Exercise - E3
# Typedata - measure
# Patient - P07
# Trial - E3_filt_measured_P07_affected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - affected
# Exercise - E3
# Typedata - measure
# Patient - P08
# Trial - E3_filt_measured_P08_affected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - affected
# Exercise - E3
# Typedata - measure
# Patient - P09
# Trial - E3_filt_measured_P09_affected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - affected
# Exercise - E3
# Typedata - measure
# Patient - P10
# Trial - E3_filt_measured_P10_affected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - affected
# Exercise - E3
# Typedata - measure
# Patient - P11
# Trial - E3_filt_measured_P11_affected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - affected
# Exercise - E3
# Typedata - measure
# Patient - P12
# Trial - E3_filt_measured_P12_affected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - affected
# Exercise - E3
# Typedata - measure
# Patient - P13
# Trial - E3_filt_measured_P13_affected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - affected
# Exercise - E3
# Typedata - measure
# Patient - P14
# Trial - E3_filt_measured_P14_affected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - affected
# Exercise - E3
# Typedata - measure
# Patient - P15
# Trial - E3_filt_measured_P15_affected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - measure
# Patient - P01
# Trial - E3_filt_measured_P01_unaffected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - measure
# Patient - P02
# Trial - E3_filt_measured_P02_unaffected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - measure
# Patient - P03
# Trial - E3_filt_measured_P03_unaffected_1.txt
# (1, 32)
# 1
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - measure
# Patient - P04
# Trial - E3_filt_measured_P04_unaffected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - measure
# Patient - P05
# Trial - E3_filt_measured_P05_unaffected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - measure
# Patient - P06
# Trial - E3_filt_measured_P06_unaffected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - measure
# Patient - P07
# Trial - E3_filt_measured_P07_unaffected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - measure
# Patient - P08
# Trial - E3_filt_measured_P08_unaffected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - measure
# Patient - P09
# Trial - E3_filt_measured_P09_unaffected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - measure
# Patient - P10
# Trial - E3_filt_measured_P10_unaffected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - measure
# Patient - P11
# Trial - E3_filt_measured_P11_unaffected_1.txt
# (9, 32)
# 9
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - measure
# Patient - P12
# Trial - E3_filt_measured_P12_unaffected_1.txt
# (4, 32)
# 4
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - measure
# Patient - P13
# Trial - E3_filt_measured_P13_unaffected_1.txt
# (4, 32)
# 4
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - measure
# Patient - P14
# Trial - E3_filt_measured_P14_unaffected_1.txt
# (4, 32)
# 4
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - measure
# Patient - P15
# Trial - E3_filt_measured_P15_unaffected_1.txt
# (4, 32)
# 4
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - measure
# Patient - S01
# Trial - E3_filt_measured_S01_unaffected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - measure
# Patient - S02
# Trial - E3_filt_measured_S02_unaffected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - measure
# Patient - S03
# Trial - E3_filt_measured_S03_unaffected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - measure
# Patient - S04
# Trial - E3_filt_measured_S04_unaffected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - measure
# Patient - S05
# Trial - E3_filt_measured_S05_unaffected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - measure
# Patient - S06
# Trial - E3_filt_measured_S06_unaffected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - measure
# Patient - S07
# Trial - E3_filt_measured_S07_unaffected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - measure
# Patient - S08
# Trial - E3_filt_measured_S08_unaffected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - measure
# Patient - S09
# Trial - E3_filt_measured_S09_unaffected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - measure
# Patient - S10
# Trial - E3_filt_measured_S10_unaffected_1.txt
# (89, 32)
# 89
# -----------------------------------------------
# TypePatient - unaffected
# Exercise - E3
# Typedata - measure
# Patient - S11
# Trial - E3_filt_measured_S11_unaffected_1.txt
# (89, 32)
# 89
# The End

# %%
import gym
from stable_baselines3.common.vec_env import DummyVecEnv
from imitation.util.util import make_vec_env
from imitation.data.wrappers import RolloutInfoWrapper
import numpy as np

class CustomEnv(gym.Env):
    def __init__(self, data, expected_actions, num_states=10, num_actions=2):
        super(CustomEnv, self).__init__()
        self.data = data
        self.num_states = num_states
        self.num_actions = num_actions
        self.expected_actions = expected_actions
        self.state = 0  # Start at beginning
        self.action_space = gym.spaces.Discrete(self.num_actions)
        self.observation_space = gym.spaces.Box(low=-np.inf, high=np.inf, shape=(self.data.shape[1],))

    def step(self, action):
        assert self.action_space.contains(action), "Invalid action!"
        is_done = False
        reward = -1.0  # Default reward when is_done is False
        expected_action = self.expected_actions[self.state]

        # Compare action and expected_action correctly
        if np.array_equal(action, expected_action):  # action matches the expected action
            reward = 1.0
        if action == 0:  # action 0 means move to the next state
            if self.state < self.num_states - 1:
                self.state += 1
            else:
                is_done = True  # End of states, the episode is done
        elif action == 1:  # action 1 means stay in the current state
            pass
        return self.data[self.state], reward, is_done, {}


    def reset(self):
        self.state = 0  # Reset to the start state
        return self.data[self.state]
# Register the environment
gym.register(
    id="custom/CustomEnv-v0",
    entry_point='__main__:CustomEnv',  # This should be the path to the class, e.g. `module:CustomEnv`
    kwargs={'data': np.array(train_data), 'expected_actions': train_actions}
)

# Create a single environment for training an expert with SB3
env = gym.make("custom/CustomEnv-v0")
# Out:
# c:\Users\Diogo\anaconda3\Lib\site-packages\gym\envs\registration.py:498: UserWarning: WARN: Overriding environment custom/CustomEnv-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")

# %%
from stable_baselines3 import PPO
from stable_baselines3.ppo import MlpPolicy
from stable_baselines3.common.evaluation import evaluate_policy
from gymnasium.wrappers import TimeLimit

expert = PPO(
    policy=MlpPolicy,
    env=env,
    seed=0,
    batch_size=64,
    ent_coef=0.0,
    learning_rate=0.0003,
    n_epochs=1,
    n_steps=64,
)

reward, _ = evaluate_policy(expert, env, 1)
print(f"Reward before training: {reward}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 17
#       4 from gymnasium.wrappers import TimeLimit
#       6 expert = PPO(
#       7     policy=MlpPolicy,
#       8     env=env,
#    (...)
#      14     n_steps=64,
#      15 )
# ---> 17 reward, _ = evaluate_policy(expert, env, 1)
#      18 print(f"Reward before training: {reward}")
#
# File c:\Users\Diogo\anaconda3\Lib\site-packages\stable_baselines3\common\evaluation.py:88, in evaluate_policy(model, env, n_eval_episodes, deterministic, render, callback, reward_threshold, return_episode_rewards, warn)
#      86 episode_starts = np.ones((env.num_envs,), dtype=bool)
#      87 while (episode_counts < episode_count_targets).any():
# ---> 88     actions, states = model.predict(
#      89         observations,  # type: ignore[arg-type]
#      90         state=states,
#      91         episode_start=episode_starts,
#      92         deterministic=deterministic,
#      93     )
#      94     new_observations, rewards, dones, infos = env.step(actions)
#      95     current_rewards += rewards
#
# File c:\Users\Diogo\anaconda3\Lib\site-packages\stable_baselines3\common\base_class.py:556, in BaseAlgorithm.predict(self, observation, state, episode_start, deterministic)
#     536 def predict(
#     537     self,
#     538     observation: Union[np.ndarray, Dict[str, np.ndarray]],
#    (...)
#     541     deterministic: bool = False,
#     542 ) -> Tuple[np.ndarray, Optional[Tuple[np.ndarray, ...]]]:
#     543     """
#     544     Get the policy action from an observation (and optional hidden state).
#     545     Includes sugar-coating to handle different observations (e.g. normalizing images).
#    (...)
#     554         (used in recurrent policies)
#     555     """
# --> 556     return self.policy.predict(observation, state, episode_start, deterministic)
#
# File c:\Users\Diogo\anaconda3\Lib\site-packages\stable_baselines3\common\policies.py:368, in BasePolicy.predict(self, observation, state, episode_start, deterministic)
#     365 obs_tensor, vectorized_env = self.obs_to_tensor(observation)
#     367 with th.no_grad():
# --> 368     actions = self._predict(obs_tensor, deterministic=deterministic)
#     369 # Convert to numpy, and reshape to the original action shape
#     370 actions = actions.cpu().numpy().reshape((-1, *self.action_space.shape))  # type: ignore[misc]
#
# File c:\Users\Diogo\anaconda3\Lib\site-packages\stable_baselines3\common\policies.py:717, in ActorCriticPolicy._predict(self, observation, deterministic)
#     709 def _predict(self, observation: PyTorchObs, deterministic: bool = False) -> th.Tensor:
#     710     """
#     711     Get the action according to the policy for a given observation.
#     712
#    (...)
#     715     :return: Taken action according to the policy
#     716     """
# --> 717     return self.get_distribution(observation).get_actions(deterministic=deterministic)
#
# File c:\Users\Diogo\anaconda3\Lib\site-packages\stable_baselines3\common\policies.py:751, in ActorCriticPolicy.get_distribution(self, obs)
#     744 """
#     745 Get the current policy distribution given the observations.
#     746
#     747 :param obs:
#     748 :return: the action distribution.
#     749 """
#     750 features = super().extract_features(obs, self.pi_features_extractor)
# --> 751 latent_pi = self.mlp_extractor.forward_actor(features)
#     752 return self._get_action_dist_from_latent(latent_pi)
#
# File c:\Users\Diogo\anaconda3\Lib\site-packages\stable_baselines3\common\torch_layers.py:225, in MlpExtractor.forward_actor(self, features)
#     224 def forward_actor(self, features: th.Tensor) -> th.Tensor:
# --> 225     return self.policy_net(features)
#
# File c:\Users\Diogo\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Diogo\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\Diogo\anaconda3\Lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File c:\Users\Diogo\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Diogo\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\Diogo\anaconda3\Lib\site-packages\torch\nn\modules\activation.py:356, in Tanh.forward(self, input)
#     355 def forward(self, input: Tensor) -> Tensor:
# --> 356     return torch.tanh(input)
#
# KeyboardInterrupt:
